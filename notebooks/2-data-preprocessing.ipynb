# %% [markdown]
# ## Preprocessing of the "domy" dataset

# %%
# to access sibling directories
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.preprocessor import DataPreprocessor
import pandas as pd
import yaml

path_data = '../data/raw/domy.csv'
path_config = '../config/preprocessor.yaml'

df = pd.read_csv(path_data)
with open(path_config, 'r') as f:
    config = yaml.safe_load(f)

p = DataPreprocessor(df, config)
p.preprocess()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17045/4294230348.py in ?()
#      14 with open(path_config, 'r') as f:
#      15     config = yaml.safe_load(f)
#      16
#      17 p = DataPreprocessor(df, config)
# ---> 18 p.preprocess()
#
# ~/_/edu/6/wsi/projekt1-regresja/src/preprocessor.py in ?(self)
#      54         self.handle_missing_values()
#      55         self.handle_outliers()
#      56         self.encode_non_numeric_data()
#      57         self.split_data()
# ---> 58         self.scale_data()
#
# ~/_/edu/6/wsi/projekt1-regresja/src/preprocessor.py in ?(self)
#     118     def scale_data(self):
# --> 119         self.scaler.fit(self.X_train)
#     120         self.X_train = self.scaler.transform(self.X_train)
#     121         self.X_test = self.scaler.transform(self.X_test)
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     920             Fitted scaler.
#     921         """
#     922         # Reset internal state before fitting
#     923         self._reset()
# --> 924         return self.partial_fit(X, y, sample_weight)
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     957             Fitted scaler.
#     958         """
#     959         xp, _, X_device = get_namespace_and_device(X)
#     960         first_call = not hasattr(self, "n_samples_seen_")
# --> 961         X = validate_data(
#     962             self,
#     963             X,
#     964             accept_sparse=("csr", "csc"),
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2898             out = y
#    2899         else:
#    2900             out = X, y
#    2901     elif not no_val_X and no_val_y:
# -> 2902         out = check_array(X, input_name="X", **check_params)
#    2903     elif no_val_X and not no_val_y:
#    2904         out = _check_y(y, **check_params)
#    2905     else:
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# ~/.cache/pypoetry/virtualenvs/projekt1-regresja-2F6BHH3U-py3.14/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: 'RL'

# %% [markdown]
# ### Steps
# 1. Handling missing data (1 column MasVnrType with nulls 60%)
# 2. Handling outliers
# 3. Encoding categorical values, handling weird numerals parsed into strings
# 4. Splitting the dataset into train and test sets
# 5. Scaling the dataset
